# %%
import matplotlib.pyplot as plt

# %%
filename = 'data/robert_frost.txt'
with open(filename, "r") as file:
    contents = file.readlines()

# %%
line_lengths = [len(line) for line in contents]

# %%
plt.hist(line_lengths, bins=20)
# Out:
# (array([744.,  50.,  49.,  20.,  39.,  42.,  44.,  27.,  50.,  65.,  78.,
#          76., 169., 334., 469., 415., 510., 330.,  88.,  10.]),
#  array([ 1.  ,  3.75,  6.5 ,  9.25, 12.  , 14.75, 17.5 , 20.25, 23.  ,
#         25.75, 28.5 , 31.25, 34.  , 36.75, 39.5 , 42.25, 45.  , 47.75,
#         50.5 , 53.25, 56.  ]),
#  <BarContainer object of 20 artists>)
